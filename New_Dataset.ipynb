# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive

drive.mount('/content/gdrive')
data = pd.read_csv('/content/gdrive/My Drive/SAMPLE_P47_SHOT_DATA.csv')
data.dropna(inplace = True)
# Out:
# Mounted at /content/gdrive

# %%
data.head()
# Out:
#   PLANT  MACHINENAME            TOOLNUMBER  PRODUCTIONRUN  PARTNUMBER  \
# 0  FR47          111  15422831 PM00 B 0009        2086494    15475295
# 1  FR47          609  12064897 PM00 B 0003        2089203    15336090
# 2  FR47          704  15326056 PMG0 B 0003        2090003    15445019
# 3  FR47          301  15304912 PMUD A 0002        2089627    15304912
# 4  FR47          510  12191648 PMTL A 0004        2088561    13626145
#
#    SERIALNUMBER           STOREDDATE  CYCLENUMBER  CYCLETIME  FILLTIME  \
# 0    4798730194  05/30/2018 01:04:27        93555      9.176     0.389
# 1    4798709333  05/30/2018 01:04:27        11398     15.800     0.587
# 2    4798745840  05/30/2018 01:04:00         3288     18.288     0.985
# 3    4798680963  05/30/2018 01:04:27        14265     16.240     0.773
# 4    4798708552  05/30/2018 01:04:27        19467     27.984     1.325
#
#    SCREWPOSITION  CUSHIONSIZE  TRANSITIONPOSITION  TRANSITIONPRESSURE  \
# ...

# %%
len(data)
# Out:
# 315837

# %%
data.isna().sum()
# Out:
# PLANT                 0
# MACHINENAME           0
# TOOLNUMBER            0
# PRODUCTIONRUN         0
# PARTNUMBER            0
# SERIALNUMBER          0
# STOREDDATE            0
# CYCLENUMBER           0
# CYCLETIME             0
# FILLTIME              0
# SCREWPOSITION         0
# CUSHIONSIZE           0
# TRANSITIONPOSITION    0
# TRANSITIONPRESSURE    0
# PEAKPRESSURE          0
# REFILLTIME            0
# ISBADPIECE            0
# dtype: int64

# %%
data.head()
# Out:
#   PLANT  MACHINENAME            TOOLNUMBER  PRODUCTIONRUN  PARTNUMBER  \
# 0  FR47          111  15422831 PM00 B 0009        2086494    15475295
# 1  FR47          609  12064897 PM00 B 0003        2089203    15336090
# 2  FR47          704  15326056 PMG0 B 0003        2090003    15445019
# 3  FR47          301  15304912 PMUD A 0002        2089627    15304912
# 4  FR47          510  12191648 PMTL A 0004        2088561    13626145
#
#    SERIALNUMBER           STOREDDATE  CYCLENUMBER  CYCLETIME  FILLTIME  \
# 0    4798730194  05/30/2018 01:04:27        93555      9.176     0.389
# 1    4798709333  05/30/2018 01:04:27        11398     15.800     0.587
# 2    4798745840  05/30/2018 01:04:00         3288     18.288     0.985
# 3    4798680963  05/30/2018 01:04:27        14265     16.240     0.773
# 4    4798708552  05/30/2018 01:04:27        19467     27.984     1.325
#
#    SCREWPOSITION  CUSHIONSIZE  TRANSITIONPOSITION  TRANSITIONPRESSURE  \
# ...

# %%
X=data[['CYCLENUMBER','CYCLETIME','FILLTIME','SCREWPOSITION','CUSHIONSIZE','TRANSITIONPOSITION','TRANSITIONPRESSURE','PEAKPRESSURE','REFILLTIME'	]]
X
# Out:
#         CYCLENUMBER  CYCLETIME  FILLTIME  SCREWPOSITION  CUSHIONSIZE  \
# 0             93555      9.176     0.389          1.320        0.227
# 1             11398     15.800     0.587          1.350        0.253
# 2              3288     18.288     0.985          3.140        0.266
# 3             14265     16.240     0.773          1.550        0.246
# 4             19467     27.984     1.325          3.660        0.245
# ...             ...        ...       ...            ...          ...
# 315832        18916     12.152     0.384          1.025        0.249
# 315833         9320     17.208     1.210          1.640        0.274
# 315834        11360     14.680     0.450          0.770        0.246
# 315835         3896     17.184     1.079          1.740        0.260
# 315836        12320     11.720     0.390          1.045        0.260
#
#         TRANSITIONPOSITION  TRANSITIONPRESSURE  PEAKPRESSURE  REFILLTIME
# ...

# %%
X.head()
# Out:
#    CYCLENUMBER  CYCLETIME  FILLTIME  SCREWPOSITION  CUSHIONSIZE  \
# 0        93555      9.176     0.389           1.32        0.227
# 1        11398     15.800     0.587           1.35        0.253
# 2         3288     18.288     0.985           3.14        0.266
# 3        14265     16.240     0.773           1.55        0.246
# 4        19467     27.984     1.325           3.66        0.245
#
#    TRANSITIONPOSITION  TRANSITIONPRESSURE  PEAKPRESSURE  REFILLTIME
# 0                0.28               13912         13982       2.460
# 1                0.28               14543         19891       3.360
# 2                0.45                5443         11169       5.644
# 3                0.32                5939         10116       5.436
# 4                0.37                7242         11672       9.580

# %%
y=data["ISBADPIECE"]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: ISBADPIECE, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
len(X_train)
# Out:
# 252669

# %%
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import sklearn

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators=760, random_state=0)

# %%
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=760, random_state=0)

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[62947    22]
#  [   21   178]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     62969
#            1       0.89      0.89      0.89       199
#
#     accuracy                           1.00     63168
#    macro avg       0.94      0.95      0.95     63168
# weighted avg       1.00      1.00      1.00     63168
#
# 0.9993192755825735

# %% [markdown]
# #Test result 99.9%

# %%
import pickle

with open('model_pickel','wb') as f:
  pickle.dump(classifier,f)

# %%
import pickle

with open('model_pickel','rb') as f:
  mod = pickle.load(f)
